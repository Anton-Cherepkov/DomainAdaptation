# %%
# !nvidia-smi
# Out:
# Tue Mar 31 11:12:15 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.44       Driver Version: 440.44       CUDA Version: 10.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 1080    On   | 00000000:04:00.0 Off |                  N/A |
# | 28%   42C    P2    51W / 180W |   8091MiB /  8119MiB |     29%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce GTX 1080    On   | 00000000:05:00.0 Off |                  N/A |
# | 27%   27C    P8     6W / 180W |   5337MiB /  8119MiB |      0%      Default |
# ...

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="5"

# %%
# from scripts.prepare_dataset import OfficeHomePreparer

# office_home_preparer = OfficeHomePreparer(
#     dataset_name='officehome',
#     dataset_root='/home/jvchizh/DomainAdaptation/datasets')

# office_home_preparer.download_dataset()

# office_home_preparer.uncompress()

# %%
from domainadaptation.experiment import DANNExperiment

# %%
config = {
    'backbone': {
        'type': 'resnet50',
        'img-size': (224, 224),
        'weights': 'imagenet',
        'pooling': 'max'},
    'dataset': {
        'classes': 65,
        'path': '/home/jvchizh/DomainAdaptation/datasets/officehome',
        'augmentations': {},
        'source': "Real World",
        'target': 'Art'},
    'batch_size': 16,
    'epochs': 5,
    'steps': 4000 // 16
}

# %%
exp = DANNExperiment(config=config)

# %%
exp.experiment_domain_adaptation()
# Out:
# Found 4357 images belonging to 65 classes.
# Found 2427 images belonging to 65 classes.
# tf.Tensor(26.261345, shape=(), dtype=float32)
# tf.Tensor(17.206306, shape=(), dtype=float32)
# tf.Tensor(19.306314, shape=(), dtype=float32)
# tf.Tensor(17.282173, shape=(), dtype=float32)
# tf.Tensor(23.825994, shape=(), dtype=float32)
# tf.Tensor(15.322816, shape=(), dtype=float32)
# tf.Tensor(17.549244, shape=(), dtype=float32)
# tf.Tensor(15.865826, shape=(), dtype=float32)
# tf.Tensor(17.454472, shape=(), dtype=float32)
# tf.Tensor(12.772988, shape=(), dtype=float32)
# tf.Tensor(17.618004, shape=(), dtype=float32)
# tf.Tensor(13.945975, shape=(), dtype=float32)
# tf.Tensor(18.259014, shape=(), dtype=float32)
# tf.Tensor(15.322675, shape=(), dtype=float32)
# tf.Tensor(14.697536, shape=(), dtype=float32)
# tf.Tensor(17.32589, shape=(), dtype=float32)
# tf.Tensor(17.069864, shape=(), dtype=float32)
# tf.Tensor(17.30508, shape=(), dtype=float32)
# tf.Tensor(17.444717, shape=(), dtype=float32)
# ...
